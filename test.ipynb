# %%
import tetris_base as tb
import numpy as np
import model

# %%
NUM_OF_GENERATIONS = 20

# %%
GA = model.GeneticAlgorithm(NUM_OF_GENERATIONS)

# %%
GA.init_chromosomes()

# %%
GA.train()

# %%
import matplotlib.pyplot as plt

HISTORY = np.array([0.05263157894736842, 0.045454545454545456, 0.05, 0.041666666666666664, 0.047619047619047616, 0.04, 0.02857142857142857, 0.03125, 0.029411764705882353, 0.029411764705882353, 0.02564102564102564, 0.024390243902439025, 0.02564102564102564, 0.024390243902439025, 0.023809523809523808, 0.024390243902439025, 0.02564102564102564, 0.023809523809523808, 0.02564102564102564, 0.024390243902439025])

# %%
# plot
plt.plot(HISTORY)
plt.xlabel('Generation')
plt.ylabel('Fitness')
plt.title('Fitness over generations')
plt.show()
